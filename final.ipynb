# %% [markdown]
# <a href="https://colab.research.google.com/github/nandyceg/Bioactivity-Prediction/blob/main/final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
dataset = pd.read_csv('padel_descriptors_lipinski_pIC50.csv')
dataset
# Out:
#       PubchemFP0  PubchemFP1  PubchemFP2  ...  HBD  HBA     pIC50
# 0              1           1           1  ...  0.0  6.0  6.124939
# 1              1           1           1  ...  0.0  5.0  7.000000
# 2              1           1           1  ...  0.0  5.0  4.301030
# 3              1           1           0  ...  0.0  5.0  6.522879
# 4              1           1           0  ...  0.0  6.0  6.096910
# ...          ...         ...         ...  ...  ...  ...       ...
# 5198           1           1           1  ...  2.0  7.0  3.379344
# 5199           1           1           1  ...  2.0  7.0  3.196065
# 5200           1           1           1  ...  2.0  7.0  3.245652
# 5201           1           1           1  ...  2.0  7.0  3.181708
# 5202           1           1           1  ...  2.0  8.0  3.071655
#
# [5203 rows x 886 columns]

# %%
X=dataset.drop(['pIC50'], axis=1)
X
# Out:
#       PubchemFP0  PubchemFP1  PubchemFP2  ...     LogP  HBD  HBA
# 0              1           1           1  ...  2.80320  0.0  6.0
# 1              1           1           1  ...  4.55460  0.0  5.0
# 2              1           1           1  ...  5.35740  0.0  5.0
# 3              1           1           0  ...  4.70690  0.0  5.0
# 4              1           1           0  ...  3.09530  0.0  6.0
# ...          ...         ...         ...  ...      ...  ...  ...
# 5198           1           1           1  ...  3.79622  2.0  7.0
# 5199           1           1           1  ...  4.14120  2.0  7.0
# 5200           1           1           1  ...  4.25030  2.0  7.0
# 5201           1           1           1  ...  3.62690  2.0  7.0
# 5202           1           1           1  ...  3.49640  2.0  8.0
#
# [5203 rows x 885 columns]

# %%
Y=dataset.iloc[:,-1]
Y
# Out:
# 0       6.124939
# 1       7.000000
# 2       4.301030
# 3       6.522879
# 4       6.096910
#           ...
# 5198    3.379344
# 5199    3.196065
# 5200    3.245652
# 5201    3.181708
# 5202    3.071655
# Name: pIC50, Length: 5203, dtype: float64

# %%
from sklearn.feature_selection import VarianceThreshold

def remove_low_variance(input_data, threshold=0.1):
    selection = VarianceThreshold(threshold)
    selection.fit(input_data)
    return input_data[input_data.columns[selection.get_support(indices=True)]]

X = remove_low_variance(X, threshold=0.1)
X
# Out:
#       PubchemFP2  PubchemFP3  PubchemFP12  ...     LogP  HBD  HBA
# 0              1           0            1  ...  2.80320  0.0  6.0
# 1              1           0            1  ...  4.55460  0.0  5.0
# 2              1           0            1  ...  5.35740  0.0  5.0
# 3              0           0            1  ...  4.70690  0.0  5.0
# 4              0           0            0  ...  3.09530  0.0  6.0
# ...          ...         ...          ...  ...      ...  ...  ...
# 5198           1           1            1  ...  3.79622  2.0  7.0
# 5199           1           1            1  ...  4.14120  2.0  7.0
# 5200           1           1            1  ...  4.25030  2.0  7.0
# 5201           1           1            1  ...  3.62690  2.0  7.0
# 5202           1           1            1  ...  3.49640  2.0  8.0
#
# [5203 rows x 211 columns]

# %%
X.to_csv('descriptor_final_list.csv', index=False)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score

# %%
model = RandomForestRegressor(n_estimators=500, random_state=42)
model.fit(X, Y)
r2 = model.score(X, Y)
r2
# Out:
# 0.8919890060423195

# %%
Y_pred = model.predict(X)
Y_pred
# Out:
# array([6.24011293, 6.81144105, 5.06806699, ..., 3.28041163, 3.18523458,
#        3.13272818])

# %%
print('Coefficient of determination (R^2): %.2f'
      % r2_score(Y, Y_pred))
# Out:
# Coefficient of determination (R^2): 0.89

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.figure(figsize=(5,5))
plt.scatter(x=Y, y=Y_pred, c="#7CAE00", alpha=0.3)

z = np.polyfit(Y, Y_pred, 1)
p = np.poly1d(z)

plt.plot(Y,p(Y),"#F8766D")
plt.ylabel('Predicted pIC50')
plt.xlabel('Experimental pIC50')
# Out:
# Text(0.5, 0, 'Experimental pIC50')

# %%
import pickle

# %%
pickle.dump(model, open('bioactivity_prediction_model.pkl','wb'))
