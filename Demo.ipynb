# %% [markdown]
# <a href="https://colab.research.google.com/github/nandyceg/Bioactivity-Prediction/blob/main/Demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install chembl_webresource_client
# Out:
# ...
#      |████████████████████████████████| 55 kB 2.1 MB/s
# ...
#      |████████████████████████████████| 596 kB 11.1 MB/s
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Attempting uninstall: itsdangerous
#     Found existing installation: itsdangerous 1.1.0
#     Uninstalling itsdangerous-1.1.0:
#       Successfully uninstalled itsdangerous-1.1.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# flask 1.1.4 requires itsdangerous<2.0,>=0.24, but you have itsdangerous 2.0.1 which is incompatible.
# ...

# %%
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %%
target = new_client.target
target_get = target.search('acetylcholinesterase')
targets = pd.DataFrame.from_dict(target_get)

# %%
targets
# Out:
#                                      cross_references  ...  tax_id
# 0   [{'xref_id': 'P22303', 'xref_name': None, 'xre...  ...    9606
# 1                                                  []  ...    9606
# 2                                                  []  ...    7227
# 3   [{'xref_id': 'P04058', 'xref_name': None, 'xre...  ...    7787
# 4   [{'xref_id': 'P21836', 'xref_name': None, 'xre...  ...   10090
# 5   [{'xref_id': 'P37136', 'xref_name': None, 'xre...  ...   10116
# 6   [{'xref_id': 'O42275', 'xref_name': None, 'xre...  ...    8005
# 7   [{'xref_id': 'P23795', 'xref_name': None, 'xre...  ...    9913
# 8                                                  []  ...    7165
# 9                                                  []  ...    7038
# 10                                                 []  ...    7539
# 11                                                 []  ...   94400
# 12                                                 []  ...    9031
# ...

# %%
selected_target = targets.target_chembl_id[0]
selected_target
# Out:
# 'CHEMBL220'

# %%
bio_activity = new_client.activity
result = bio_activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(result)
df
# Out:
#      activity_comment  activity_id  ... upper_value  value
# 0                None        33969  ...        None   0.75
# 1                None        37563  ...        None    0.1
# 2                None        37565  ...        None   50.0
# 3                None        38902  ...        None    0.3
# 4                None        41170  ...        None    0.8
# ...               ...          ...  ...         ...    ...
# 7544             None     20703835  ...        None   0.74
# 7545             None     20703856  ...        None   0.51
# 7546             None     20708928  ...        None  125.0
# 7547             None     20708929  ...        None  100.0
# 7548             None     20708930  ...        None    0.1
#
# [7549 rows x 45 columns]

# %%
df.standard_type.unique()
# Out:
# array(['IC50'], dtype=object)

# %%
df
# Out:
#      activity_comment  activity_id  ... upper_value  value
# 0                None        33969  ...        None   0.75
# 1                None        37563  ...        None    0.1
# 2                None        37565  ...        None   50.0
# 3                None        38902  ...        None    0.3
# 4                None        41170  ...        None    0.8
# ...               ...          ...  ...         ...    ...
# 7544             None     20703835  ...        None   0.74
# 7545             None     20703856  ...        None   0.51
# 7546             None     20708928  ...        None  125.0
# 7547             None     20708929  ...        None  100.0
# 7548             None     20708930  ...        None    0.1
#
# [7549 rows x 45 columns]

# %%
df = df[df.standard_value.notna()]
df
# Out:
#      activity_comment  activity_id  ... upper_value  value
# 0                None        33969  ...        None   0.75
# 1                None        37563  ...        None    0.1
# 2                None        37565  ...        None   50.0
# 3                None        38902  ...        None    0.3
# 4                None        41170  ...        None    0.8
# ...               ...          ...  ...         ...    ...
# 7544             None     20703835  ...        None   0.74
# 7545             None     20703856  ...        None   0.51
# 7546             None     20708928  ...        None  125.0
# 7547             None     20708929  ...        None  100.0
# 7548             None     20708930  ...        None    0.1
#
# [6342 rows x 45 columns]

# %%
df.to_csv('bioactivity.csv',index=False)

# %%
bioactivity_col = []
for i in df.standard_value:
  if float(i) <= 1000:
    bioactivity_col.append("active")
  elif float(i)>= 10000:
    bioactivity_col.append("inactive")
  else:
    bioactivity_col.append("intermediate")

# %%
selected_cols = ['molecule_chembl_id','canonical_smiles','standard_value']
df = df[selected_cols]
df
# Out:
#      molecule_chembl_id  ... standard_value
# 0          CHEMBL133897  ...          750.0
# 1          CHEMBL336398  ...          100.0
# 2          CHEMBL131588  ...        50000.0
# 3          CHEMBL130628  ...          300.0
# 4          CHEMBL130478  ...          800.0
# ...                 ...  ...            ...
# 7544      CHEMBL4645659  ...          740.0
# 7545       CHEMBL513063  ...          510.0
# 7546      CHEMBL4640608  ...       125000.0
# 7547      CHEMBL4173961  ...       100000.0
# 7548           CHEMBL95  ...          100.0
#
# [6342 rows x 3 columns]

# %%
bioactivity_col = pd.Series(bioactivity_col, name='bioactivity_status')
df = pd.concat([df,bioactivity_col],axis=1)

# %%
df
# Out:
#      molecule_chembl_id  ... bioactivity_status
# 0          CHEMBL133897  ...             active
# 1          CHEMBL336398  ...             active
# 2          CHEMBL131588  ...           inactive
# 3          CHEMBL130628  ...             active
# 4          CHEMBL130478  ...             active
# ...                 ...  ...                ...
# 7544      CHEMBL4645659  ...                NaN
# 7545       CHEMBL513063  ...                NaN
# 7546      CHEMBL4640608  ...                NaN
# 7547      CHEMBL4173961  ...                NaN
# 7548           CHEMBL95  ...                NaN
#
# [7479 rows x 4 columns]

# %%
df = df[df.bioactivity_status.notna()]
df
# Out:
#      molecule_chembl_id  ... bioactivity_status
# 0          CHEMBL133897  ...             active
# 1          CHEMBL336398  ...             active
# 2          CHEMBL131588  ...           inactive
# 3          CHEMBL130628  ...             active
# 4          CHEMBL130478  ...             active
# ...                 ...  ...                ...
# 6337      CHEMBL4089550  ...             active
# 6338      CHEMBL4102122  ...             active
# 6339      CHEMBL4077866  ...           inactive
# 6340      CHEMBL4064154  ...           inactive
# 6341      CHEMBL4085722  ...             active
#
# [5203 rows x 4 columns]

# %%
df.to_csv('bioactivity_preprocessed.csv',index=False)
df
# Out:
#      molecule_chembl_id  ... bioactivity_status
# 0          CHEMBL133897  ...             active
# 1          CHEMBL336398  ...             active
# 2          CHEMBL131588  ...           inactive
# 3          CHEMBL130628  ...             active
# 4          CHEMBL130478  ...             active
# ...                 ...  ...                ...
# 6337      CHEMBL4089550  ...             active
# 6338      CHEMBL4102122  ...             active
# 6339      CHEMBL4077866  ...           inactive
# 6340      CHEMBL4064154  ...           inactive
# 6341      CHEMBL4085722  ...             active
#
# [5203 rows x 4 columns]

# %%
ls-l
# Out:
# total 3680
# -rw-r--r-- 1 root root 3348511 Oct 28 11:30 bioactivity.csv
# -rw-r--r-- 1 root root  412614 Oct 28 11:32 bioactivity_preprocessed.csv
# drwxr-xr-x 1 root root    4096 Oct 26 13:34 sample_data/
